# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip 
# !./ngrok authtoken <YOUR NGROK AUTH TOKEN>

# %%
import os
os.environ["AWS_S3_ACCESS_KEY_ID"] = "<YOUR AWS ACCESS KEY>"
os.environ["AWS_S3_SECRET_ACCESS_KEY"] = "<YOUR AWS SECRET ACCESS KEY>"

# %%
import os
import multiprocessing


pool = multiprocessing.Pool(processes = 3)
results_of_processes = [pool.apply_async(os.system, args=(cmd, ), callback = None )
                        for cmd in [
                        f"tensorboard --logdir /kaggle/working/tensorboard/runs/ --host 0.0.0.0 --port 6006 &",
                        "/kaggle/working/ngrok http 6006 &"
                        ]]

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %%
import time
time.sleep(30)

# %%
! git clone https://github.com/dmdgik/code_language_detection.git
# %cd code_language_detection
# !pip install -q -r requirements.txt
# %cd src/CodeLanguageDetector/running_scripts

# %%
! accelerate launch train_bert.py --experiment_config="../../../configs/kaggle_experiment_bert.yaml"

# %%
# %cd /kaggle/working
# import os
# mypath = "/kaggle/working/" #Enter your path here
# for root, dirs, files in os.walk(mypath, topdown=False):
#     for file in files:
#         os.remove(os.path.join(root, file))

#     # Add this block to remove folders
#     for dir in dirs:
#         os.rmdir(os.path.join(root, dir))
